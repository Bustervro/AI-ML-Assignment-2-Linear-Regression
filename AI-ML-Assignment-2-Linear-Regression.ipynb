# %% [markdown]
# # AI-ML-Assignment-2-Linear-Regression
#
# Author: ADEN OSMAN
#
# This notebook contains the steps for data loading, cleaning, feature engineering, model training, and evaluation.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

print('Notebook code cell placeholder: the full analysis is saved in the repository README and outputs.')

# %% [markdown]
# ## Dataset used
# - Diabetes (sklearn.load_diabetes) - used as fallback
#
# ## Selected feature and engineered feature
# - Selected numerical feature: **age**
# - Engineered feature: **age_squared**

# %% [markdown]
# ## Evaluation metrics
# - MSE: 5649.6516
# - R2: 0.0344

# %% [markdown]
# ## Plot
#
# The file `regression_scatter_line.png` shows the scatter plot with the regression line (engineered feature held at median).
